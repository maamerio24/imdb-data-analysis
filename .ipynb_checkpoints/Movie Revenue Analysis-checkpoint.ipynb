# %% [markdown]
# # Top Earners in Movie Industry
#
# ## Table of Contents
#
# <ul>
#     <li><a href="#intro">Introduction</a></li>
#     <li><a href="#eda">Exploratory Data Analysis</a></li>
#     <li><a href="#conclusion">Conclusion</a></li>
# </ul>

# %% [markdown]
# <a id="#intro"></a>
# ## Introduction
#
# > This analysis project is to be done using the imdb movie data. When the analysis is completed, you should be able to find the top 5 highest grossing directors, the top 5 highest grossing movie genres of all time, comparing the revenue of the highest grossing movies and which companies released the most movies.
#
# > There are 10 columns that will not be needed for the analysis. Use pandas to drop these columns. HINT: Only the columns pertaining to revenue will be needed.
#
# > To get you started, I've already placed the needed code for getting the packages and datafile that you will be using for the project.

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imdb-movies.csv')

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# ### Drop columns without neccesary information and remove all records with no financial information -- Pay close attention to things that don't tell you anything regarding financial data

# %%
df.drop(['imdb_id', 'popularity', 'cast', 'homepage', 'tagline', 'keywords', 'overview', 'runtime', 'vote_count', 'vote_average'], axis=1, inplace=True)

# %%
df
# Out:
#            id     budget     revenue                original_title  \
# 0      135397  150000000  1513528810                Jurassic World
# 1       76341  150000000   378436354            Mad Max: Fury Road
# 2      262500  110000000   295238201                     Insurgent
# 3      140607  200000000  2068178225  Star Wars: The Force Awakens
# 4      168259  190000000  1506249360                     Furious 7
# ...       ...        ...         ...                           ...
# 10861      21          0           0            The Endless Summer
# 10862   20379          0           0                    Grand Prix
# 10863   39768          0           0           Beregis Avtomobilya
# 10864   21449          0           0        What's Up, Tiger Lily?
# 10865   22293      19000           0      Manos: The Hands of Fate
#
#                  director                                     genres  \
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# ...

# %% [markdown]
# ### Data Cleaning

# %%
# Delete all records with null, or empty values
df.isnull().sum()
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# id                      0
# budget                  0
# revenue                 0
# original_title          0
# director                0
# genres                  0
# production_companies    0
# release_date            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %% [markdown]
# #### Here's a helpful hint from my own analysis when I ran this the first time. This may help shed light on what your data set should look like.
#
# #### If I created one record for each the `production_companies` a movie was release under and one record each for `genres`<br>and tried to run calculations, it wouldn't work because for many records, the amount of `production_companies`<br>and `genres` aren't the same, so I'll create 2 dataframes; one w/o a `production_companies` column and one w/o a `genres` columns

# %%
df_genre = df.drop(['production_companies'], axis=1)
df_production = df.drop(['genres'], axis=1)

# %%
df_genre
# Out:
#            id     budget     revenue                original_title  \
# 0      135397  150000000  1513528810                Jurassic World
# 1       76341  150000000   378436354            Mad Max: Fury Road
# 2      262500  110000000   295238201                     Insurgent
# 3      140607  200000000  2068178225  Star Wars: The Force Awakens
# 4      168259  190000000  1506249360                     Furious 7
# ...       ...        ...         ...                           ...
# 10861      21          0           0            The Endless Summer
# 10862   20379          0           0                    Grand Prix
# 10863   39768          0           0           Beregis Avtomobilya
# 10864   21449          0           0        What's Up, Tiger Lily?
# 10865   22293      19000           0      Manos: The Hands of Fate
#
#                  director                                     genres  \
# 0         Colin Trevorrow  Action|Adventure|Science Fiction|Thriller
# ...

# %%
df_production
# Out:
#            id     budget     revenue                original_title  \
# 0      135397  150000000  1513528810                Jurassic World
# 1       76341  150000000   378436354            Mad Max: Fury Road
# 2      262500  110000000   295238201                     Insurgent
# 3      140607  200000000  2068178225  Star Wars: The Force Awakens
# 4      168259  190000000  1506249360                     Furious 7
# ...       ...        ...         ...                           ...
# 10861      21          0           0            The Endless Summer
# 10862   20379          0           0                    Grand Prix
# 10863   39768          0           0           Beregis Avtomobilya
# 10864   21449          0           0        What's Up, Tiger Lily?
# 10865   22293      19000           0      Manos: The Hands of Fate
#
#                  director                               production_companies  \
# 0         Colin Trevorrow  Universal Studios|Amblin Entertainment|Legenda...
# ...

# %% [markdown]
# <a id="eda"></a>
# ## Exploratory Data Analysis
#
# > Use Matplotlib to display your data analysis

# %% [markdown]
# ### Which production companies released the most movies in the last 10 years? Display the top 5 production companies.

# %%
#found this nifty trick online to combine setting the column = str and then exploding all in one step.
df_production = df_production.assign(production_companies=df.production_companies.str.split("|")).explode('production_companies').reset_index(drop=True)

# %%
busy_bees = df_production.groupby(['production_companies']).count()[['id']]
best_busy_bees = busy_bees.sort_values(by = ['id'],ascending=False).head(5)

best_busy_bees.plot.barh(xlabel='Production Companies', ylabel='Number of Movies Released', grid=True, title='Production Companies with Most Releases', figsize=(15,10))
plt.legend(["# of releases"]);

# %% [markdown]
# ### What 5 movie genres grossed the highest all-time?

# %%
df_genre = df_genre.assign(genres=df.genres.str.split("|")).explode('genres').reset_index(drop=True)

# %%
highest_grossed = df_genre.groupby(['genres']).sum()[['revenue']]
money_makers = highest_grossed.sort_values(by = ['revenue'], ascending=False).head(5)


money_makers.plot.bar(xlabel='Genres', ylabel='($) Grossed', grid=True, title='Hghest Grossing Genres', figsize=(15,10))
plt.legend(["# of releases"]);

# %% [markdown]
# ### Who are the top 5 grossing directors?

# %%
goat_directors = df.groupby(['director']).sum()[['revenue']]
directors_pie = goat_directors.sort_values(by = ['revenue'], ascending=False).head(5)

directors_pie.plot.pie(subplots=True, figsize=(15, 14));

# %% [markdown]
# ### Compare the revenue of the highest grossing movies of all time.

# %%
goat_movies = df.groupby(['original_title']).sum()[['revenue']]
most_pop_movies = goat_movies.sort_values(by = ['revenue'], ascending=False).head(10)
most_pop_movies.plot.pie(subplots=True, figsize=(20, 20));

# %% [markdown]
# <a id="conclusions"></a>
# ## Conclusions
#
# > Using the cell below, write a brief conclusion of what you have found from the anaylsis of the data. The Cell below will allow you to write plan text instead of code.

# %%
#It was very interesting to see how the various studios stacked up against each other, as I really wasn't sure which
#studio was the highest grossing. It's pretty apparent that the highest grossing studios, directors, and movies
#are all pretty correlated, which makes sense. It's also crazy to see how Avatar stood the test of time, as of 
#5 years ago, since we all know how well Endgame and Infinity War have done in terms of box office success.
